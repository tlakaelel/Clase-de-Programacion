# %%
num1 = randint(1, 2^128);
num2 = randint(1, 2^128);

# %%
print(num1)
print(num2)
# Out:
# 22635304507474675523329936631583558841
# 26161821275031753591373744720926936057

# %%
num1*num2
# Out:
# 592180791030473114839925527868232456812254067675700351357972995218104029937
